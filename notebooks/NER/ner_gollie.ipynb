# %%
import os
os.chdir("/teamspace/studios/this_studio/mapping_reform")

import sys
sys.path.append(os.path.abspath("./GoLLIE"))

# %%
import rich
import logging
from src.model.load_model import load_model
import black
import inspect
from jinja2 import Template as jinja2Template
import tempfile
from src.tasks.utils_typing import AnnotationList
logging.basicConfig(level=logging.INFO)
from typing import Dict, List, Type
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 3
#       1 import rich
#       2 import logging
# ----> 3 from src.model.load_model import load_model
#       4 import black
#       5 import inspect
#
# File ~/mapping_reform/GoLLIE/src/model/load_model.py:8
#       4 from typing import List, Optional, Tuple, Union
#       6 import torch
# ----> 8 from transformers import (
#       9     AutoConfig,
#      10     AutoModelForCausalLM,
#      11     AutoModelForSeq2SeqLM,
#      12     AutoTokenizer,
#      13     BitsAndBytesConfig,
#      14     PreTrainedModel,
#      15     PreTrainedTokenizerBase,
#      16 )
#      17 from transformers.models.auto.modeling_auto import (
#      18     MODEL_FOR_CAUSAL_LM_MAPPING_NAMES,
#      19     MODEL_FOR_SEQ_TO_SEQ_CAUSAL_LM_MAPPING_NAMES,
#      20 )
#      21 from transformers.utils import is_ipex_available
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/transformers/utils/import_utils.py:2154, in _LazyModule.__getattr__(self, name)
#    2152 elif name in self._class_to_module.keys():
#    2153     try:
# -> 2154         module = self._get_module(self._class_to_module[name])
#    2155         value = getattr(module, name)
#    2156     except (ModuleNotFoundError, RuntimeError) as e:
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/transformers/utils/import_utils.py:2184, in _LazyModule._get_module(self, module_name)
#    2182     return importlib.import_module("." + module_name, self.__name__)
#    2183 except Exception as e:
# -> 2184     raise e
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/transformers/utils/import_utils.py:2182, in _LazyModule._get_module(self, module_name)
#    2180 def _get_module(self, module_name: str):
#    2181     try:
# -> 2182         return importlib.import_module("." + module_name, self.__name__)
#    2183     except Exception as e:
#    2184         raise e
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/transformers/modeling_utils.py:59
#      57 from .integrations.deepspeed import _load_state_dict_into_zero3_model
#      58 from .integrations.eager_paged import eager_paged_attention_forward
# ---> 59 from .integrations.flash_attention import flash_attention_forward
#      60 from .integrations.flash_paged import paged_attention_forward
#      61 from .integrations.flex_attention import flex_attention_forward
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/transformers/integrations/flash_attention.py:5
#       1 from typing import Optional
#       3 import torch
# ----> 5 from ..modeling_flash_attention_utils import _flash_attention_forward, flash_attn_supports_top_left_mask
#       6 from ..utils import logging
#       9 logger = logging.get_logger(__name__)
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/transformers/modeling_flash_attention_utils.py:100
#      98 FA_VERSION = None
#      99 if is_flash_attn_2_available():
# --> 100     from flash_attn import flash_attn_func as flash_attn_2_func
#     101     from flash_attn import flash_attn_varlen_func as flash_attn_2_varlen_func
#     102     from flash_attn.bert_padding import pad_input as pad_input_fa2
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/flash_attn/__init__.py:3
#       1 __version__ = "2.8.1"
# ----> 3 from flash_attn.flash_attn_interface import (
#       4     flash_attn_func,
#       5     flash_attn_kvpacked_func,
#       6     flash_attn_qkvpacked_func,
#       7     flash_attn_varlen_func,
#       8     flash_attn_varlen_kvpacked_func,
#       9     flash_attn_varlen_qkvpacked_func,
#      10     flash_attn_with_kvcache,
#      11 )
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/flash_attn/flash_attn_interface.py:15
#      13     from .flash_attn_triton_amd import interface_fa as flash_attn_gpu
#      14 else:
# ---> 15     import flash_attn_2_cuda as flash_attn_gpu
#      17 # isort: on
#      19 def maybe_contiguous(x):
#
# ImportError: /usr/lib/x86_64-linux-gnu/libc.so.6: version `GLIBC_2.32' not found (required by /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/flash_attn_2_cuda.cpython-310-x86_64-linux-gnu.so)
